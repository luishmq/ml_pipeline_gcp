# %%
from google.cloud import storage
from io import StringIO
import pandas as pd

storage_client = storage.Client()

bucket = storage_client.bucket("data_pipeline_paris")
blob = bucket.blob("ParisHousing.csv")

content = blob.download_as_string()
df = pd.read_csv(StringIO(content.decode('utf-8')))

df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
import numpy as np
from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder

# %%
df = df.drop(columns=['cityCode'])

# %%
df['hasYard'] = df['hasYard'].astype(object)
df['hasPool'] = df['hasPool'].astype(object)
df['hasStormProtector'] = df['hasStormProtector'].astype(object)
df['isNewBuilt'] = df['isNewBuilt'].astype(object)
df['hasStorageRoom'] = df['hasStorageRoom'].astype(object)

# %%
import pandas as pd
from pycaret.regression import RegressionExperiment, load_model, predict_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

s = RegressionExperiment()
s.setup(df, target='price', normalize=True, normalize_method='minmax', ignore_features=['cityCode'], session_id=123)

best_model = s.compare_models()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/luishmq/Documents/santodigital/vertexai/notebooks/pipeline.ipynb Célula 5 line 6
#       <a href='vscode-notebook-cell:/Users/luishmq/Documents/santodigital/vertexai/notebooks/pipeline.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
#       <a href='vscode-notebook-cell:/Users/luishmq/Documents/santodigital/vertexai/notebooks/pipeline.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> s = RegressionExperiment()
# ----> <a href='vscode-notebook-cell:/Users/luishmq/Documents/santodigital/vertexai/notebooks/pipeline.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> s.setup(df, target='price', normalize=True, normalize_method='minmax', ignore_features=['cityCode'], session_id=123)
# ...

# %%
predictions = predict_model(best_model, data=df)
